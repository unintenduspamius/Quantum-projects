# %%
print("hello quantum world")
# Out:
# hello quantum world

# %%
# Simulate a coin flip using Python
import random

coin = random.choice(["Qubit collapsed to |0⟩", "Qubit collapsed to |1⟩"])
print("Quantum measurement result:", coin)
# Out:
# Quantum measurement result: Qubit collapsed to |0⟩

# %% [markdown]
# # Project 001: Hello Quantum World
# This is my first notebook in Colab. I’ve written basic Python code and simulated a qubit measurement using randomness.
